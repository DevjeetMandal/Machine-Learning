# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
str1 = pd.read_csv(r"C:\Users\devje\OneDrive\Desktop\MCCAI\Machicne Learning\Main Project\StellarClassification\star_classification.csv")

# %%
str1.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# ...

# %%
str1.info
# Out:
# <bound method DataFrame.info of              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
# ...

# %%
str1.dtypes
# Out:
# obj_ID         float64
# alpha          float64
# delta          float64
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# run_ID           int64
# rerun_ID         int64
# cam_col          int64
# field_ID         int64
# spec_obj_ID    float64
# class           object
# redshift       float64
# plate            int64
# MJD              int64
# fiber_ID         int64
# dtype: object

# %%
str1.isnull().sum()
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %%
for i in str1.columns:
    print(f"{i} : {str1[i].unique()}")
# Out:
# obj_ID : [1.23766096e+18 1.23766488e+18 1.23766096e+18 ... 1.23766830e+18
#  1.23766115e+18 1.23766115e+18]
# alpha : [135.6891066  144.82610055 142.18878956 ... 224.58740744 212.26862112
#  196.89605297]
# delta : [32.49463184 31.27418489 35.58244418 ... 15.70070739 46.66036528
#  49.46464277]
# u : [23.87882 24.77759 25.26307 ... 21.16916 25.35039 22.62171]
# g : [22.2753  22.83188 22.66389 ... 19.26997 21.63757 21.79745]
# r : [20.39501 22.58444 20.60976 ... 18.20428 19.91386 20.60115]
# i : [19.16573 21.16812 19.34857 ... 17.69034 19.07254 20.00959]
# z : [18.79371 21.61427 18.94827 ... 20.73569 17.35221 18.62482]
# run_ID : [3606 4518 4192 8102 7773 3716 5934 3927 8157 7712 1412 2821 3015 5416
#  6574 7675 2126 2777 3530 6573 3893 5972 4576 8096 3841 6366 7718 5322
#  5112 1904 3926 4470 8100 3557 4836 2825 2243 4828 5137 4504 1739 4822
#  3910 8067 4263 1140 4880 8038 2190 5313 1907 5327 3830 7717 4671 8095
# ...

# %%
str1 = str1.drop(["spec_obj_ID", "plate", "MJD", "fiber_ID", "obj_ID", "run_ID", "rerun_ID", "field_ID"], axis = 1)

# %%
str1 = str1.drop("cam_col", axis = 1)

# %%
str1.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#     class  redshift
# 0  GALAXY  0.634794
# 1  GALAXY  0.779136
# 2  GALAXY  0.644195
# 3  GALAXY  0.932346
# 4  GALAXY  0.116123

# %%
sns.scatterplot(x = str1["alpha"], y = str1["delta"], hue = str1["class"])
plt.show()

# %%
sns.boxplot(x='class', y='redshift', data=str1)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
str1["class"] = le.fit_transform(str1["class"])

# %%
c = str1.corr()

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(c, annot = True)
plt.show()

# %%
ip = str.drop("class", axis = 1)

# %%
op = str["class"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(ip, op, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
xtrain = sc.fit_transform(xtrain)

# %%
xtest = sc.transform(xtest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(criterion = "entropy")

# %%
rfc.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
pred = rfc.predict(xtest)
pred
# Out:
# array([2, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
acc = accuracy_score(ytest, pred)
rec = recall_score(ytest, pred, average = "weighted")
pre = precision_score(ytest, pred, average = "weighted")
f1 = f1_score(ytest, pred, average = "weighted")

print(f"Accuracy - {acc}")
print(f"Recall - {rec}")
print(f"Precision - {pre}")
print(f"F1 Score - {f1}")
# Out:
# Accuracy - 0.9791
# Recall - 0.9791
# Precision - 0.9789996788717461
# F1 Score - 0.9789708866380508

# %%
import xgboost
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(xtrain, ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
pred1 = model.predict(xtest)

# %%
pred1
# Out:
# array([2, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
acc1 = accuracy_score(ytest, pred1)
rec1 = recall_score(ytest, pred1, average = "weighted")
pre1 = precision_score(ytest, pred1, average = "weighted")
f11 = f1_score(ytest, pred1, average = "weighted")

print(f"Accuracy - {acc1}")
print(f"Recall - {rec1}")
print(f"Precision - {pre1}")
print(f"F1 Score - {f11}")
# Out:
# Accuracy - 0.9754
# Recall - 0.9754
# Precision - 0.9753055502239364
# F1 Score - 0.9753041384296943

# %%
# import joblib
# joblib.dump(rfc, "StellarModel.joblib")

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(ytest, pred)
cm
# Out:
# array([[11683,   124,    27],
#        [  264,  3534,     0],
#        [    3,     0,  4365]], dtype=int64)

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot(cmap='cool')
plt.show()

# %%
str1[str1['class']=='STAR'].sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 str[str['class']=='STAR'].sample(5)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
# ...
